# %%
# !pip install pytesseract
# !pip install opencv-python
# !pip install nltk

# %%
import cv2
import pytesseract
import torch
from transformers import pipeline
from transformers import BartForConditionalGeneration, BartTokenizer


def img2text(img_path):

    image = cv2.imread(imgpath)

    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # pytesseract to extract from gray
    extracted_text = pytesseract.image_to_string(gray)

    return extracted_text

def summarization(text, max_length=200):
    model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")

    # Tokenize and generate a summary
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=max_length, truncation=True)
    summary_ids = model.generate(inputs, max_length=max_length, min_length=10, length_penalty=3.0, num_beams=10, early_stopping=True)

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

if __name__ == "__main__":

    imgpath = "/content/download (2).jpeg"

    try:
        # Extract text from the image using OCR
        extracted_text = img2text(image_path)

        print("Extracted Text:")
        print(extracted_text)

        # Generate a summary from the extracted text
        summary = summarization(extracted_text)

        print("\nImage Summary:")
        print(summary)

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Extracted Text:
# ‘The University’s decision to join the University Athletic Associ
# ation is, at first glance, an exciting venture. it seems more
# Appropriate for the U of C to compete athletically against un
# versities they compete with intellectually More meaningful rv
# aries ean be built around sehools with which the student body Is
# Already familiar. And if the concept of rival athletic school
# ‘atches on, the quality of student life qn campus will he improved by
# this new diversion. More high schoo! students will hear of the
# University of Chieago. This leads to more and better applicants to
# the college, and a larger class size. Alumni Associations wil be able
# to show off a new crop of bright, promising student-athletes to
# lumi hungry for contaet with their old college. Tis leads to more:
# donations to the school And with more students paving tuition and
# Spire Oncaitsine:
#
#
# Image Summary:
# ...
